# %%
import numpy as np
import pandas as pd

# %%
df_gods=pd.read_csv("/content/greek_gods.csv")
df_goddesses=pd.read_csv("/content/greek_goddesses.csv")

# %%
# df_gods['Gender'] = 'God'
# df_godesses['Gender']='Godess'

# %%
df_gods
# Out:
#         God                 Domain       Symbol    Age
# 0      Zeus       King of the Gods  Thunderbolt  10000
# 1  Poseidon         God of the Sea      Trident   9000
# 2      Hera      Queen of the Gods      Peacock   8500
# 3    Athena      Goddess of Wisdom          Owl   8000
# 4     Hades  God of the Underworld       Helmet   9500

# %%
df_goddesses
# Out:
#           God                   Domain         Symbol   Age
# 0   Aphrodite          Goddess of Love           Dove  7000
# 1     Artemis      Goddess of the Hunt  Bow and Arrow  7500
# 2     Demeter   Goddess of Agriculture          Wheat  8000
# 3      Hestia    Goddess of the Hearth           Fire  8200
# 4  Persephone  Queen of the Underworld    Pomegranate  7800

# %% [markdown]
# 1. Merge the data from greek_gods.csv and greek_goddesses.csv based on a common field and create a new table that includes information about both gods and goddesses.

# %%
df = pd.concat([df_gods, df_goddesses], ignore_index=True)

# %%
df
# Out:
#           God                   Domain         Symbol    Age
# 0        Zeus         King of the Gods    Thunderbolt  10000
# 1    Poseidon           God of the Sea        Trident   9000
# 2        Hera        Queen of the Gods        Peacock   8500
# 3      Athena        Goddess of Wisdom            Owl   8000
# 4       Hades    God of the Underworld         Helmet   9500
# 5   Aphrodite          Goddess of Love           Dove   7000
# 6     Artemis      Goddess of the Hunt  Bow and Arrow   7500
# 7     Demeter   Goddess of Agriculture          Wheat   8000
# 8      Hestia    Goddess of the Hearth           Fire   8200
# 9  Persephone  Queen of the Underworld    Pomegranate   7800

# %% [markdown]
# 2. Filter the merged table to only include gods and goddesses who are older than 8000 years, then sort them based on their ages in descending order.

# %%
df2 =df[df['Age'] > 8000].sort_values(by='Age', ascending=False)

print(df2)
# Out:
#         God                 Domain       Symbol    Age
# 0      Zeus       King of the Gods  Thunderbolt  10000
# 4     Hades  God of the Underworld       Helmet   9500
# 1  Poseidon         God of the Sea      Trident   9000
# 2      Hera      Queen of the Gods      Peacock   8500
# 8    Hestia  Goddess of the Hearth         Fire   8200

# %% [markdown]
# 3. Join the two tables based on the "Domain" field and calculate the average age of gods and goddesses in each domain.

# %%
common_domains = set(df_gods['Domain']).intersection(set(df_goddesses['Domain']))
print("Common Domains:", common_domains)
# Out:
# Common Domains: set()

# %%
# Merge the two dataframes based on the 'Domain' column
df3 = pd.merge(df_gods, df_goddesses, on='Domain', suffixes=('_god', '_goddess'))

# Calculate the average age for each domain
average_age_by_domain = df3.groupby('Domain')[['Age_god', 'Age_goddess']].mean()

print(average_age_by_domain)


df3
# Out:
# Empty DataFrame
# Columns: [Age_god, Age_goddess]
# Index: []
# Empty DataFrame
# Columns: [God_god, Domain, Symbol_god, Age_god, God_goddess, Symbol_goddess, Age_goddess]
# Index: []

# %% [markdown]
# There are no common domain

# %%
# Calculate the average age of gods and goddesses in each domain
avg_age_per_domain = df3.groupby('Domain')['Age'].mean()

print(avg_age_per_domain)
# Out:
# Domain
# Agriculture                       8500.0
# Fire & Metalworking               3500.0
# Hearth & Home                     3000.0
# Love & Beauty                     4500.0
# Music, Poetry, Light, Healing     8200.0
# Olympian                          6000.0
# Sea                               5500.0
# Time                             10000.0
# Underworld                        5000.0
# War                               4000.0
# Wisdom & Crafts                   7000.0
# Name: Age, dtype: float64

# %% [markdown]
# 4. Determine which god/goddess has the highest age, and then find out if they are a god or a goddess.

# %%
import pandas as pd

# Load the data from CSV files
gods_df = pd.read_csv('greek_gods.csv')
goddesses_df = pd.read_csv('greek_goddesses.csv')

# Add a 'Gender' column to differentiate between gods and goddesses
gods_df['Gender'] = 'God'
goddesses_df['Gender'] = 'Goddess'

# Concatenate the DataFrames
df4 = pd.concat([gods_df, goddesses_df], ignore_index=True)

# Find the entry with the highest age
max_age_entry = df4.loc[df4['Age'].idxmax()]

# Determine if the entry is a god or a goddess
highest_age_name = max_age_entry['God'] if 'God' in max_age_entry else max_age_entry['Goddess']
highest_age_gender = max_age_entry['Gender']

print(f"The {highest_age_gender.lower()} with the highest age is {highest_age_name}, aged {max_age_entry['Age']}.")
# Out:
# The god with the highest age is Zeus, aged 10000.

# %% [markdown]
# 5. Create a new column in each table called "Age Group" and categorize the gods/goddesses into groups such as "Young" (age < 5000), "Middle-aged" (age between 5000 and 8000), and "Old" (age > 8000)

# %%
# Define a function to categorize age into groups
def categorize_age(age):
    if age < 5000:
        return 'Young'
    elif 5000 <= age < 8000:
        return 'Middle-aged'
    elif age >= 8000:
        return 'Old'
    else:
        return 'Unknown'

# Apply the function to create the "Age Group" column
df_gods['Age Group'] = df_gods['Age'].apply(categorize_age)
df_goddesses['Age Group'] = df_goddesses['Age'].apply(categorize_age)

# Display the updated tables
print("Table for Gods:")
print(df_gods)
print("\nTable for Goddesses:")
print(df_goddesses)
# Out:
# Table for Gods:
#         God                 Domain       Symbol    Age Age Group
# 0      Zeus       King of the Gods  Thunderbolt  10000       Old
# 1  Poseidon         God of the Sea      Trident   9000       Old
# 2      Hera      Queen of the Gods      Peacock   8500       Old
# 3    Athena      Goddess of Wisdom          Owl   8000       Old
# 4     Hades  God of the Underworld       Helmet   9500       Old
#
# Table for Goddesses:
#           God                   Domain         Symbol   Age    Age Group
# 0   Aphrodite          Goddess of Love           Dove  7000  Middle-aged
# 1     Artemis      Goddess of the Hunt  Bow and Arrow  7500  Middle-aged
# 2     Demeter   Goddess of Agriculture          Wheat  8000          Old
# 3      Hestia    Goddess of the Hearth           Fire  8200          Old
# 4  Persephone  Queen of the Underworld    Pomegranate  7800  Middle-aged

# %% [markdown]
# 6. Compare the average ages of gods and goddesses. Is there a significant age difference between them? If yes, which group tends to be older?

# %%
# Calculate the average age of gods and goddesses separately
avg_age_gods = df_gods['Age'].mean()
avg_age_goddesses = df_goddesses['Age'].mean()

# Determine if there is a significant age difference
if avg_age_gods > avg_age_goddesses:
    print("Gods tend to be older than goddesses.")
    print(f"The average age of gods is {avg_age_gods:.2f} years.")
    print(f"The average age of goddesses is {avg_age_goddesses:.2f} years.")
elif avg_age_gods < avg_age_goddesses:
    print("Goddesses tend to be older than gods.")
    print(f"The average age of gods is {avg_age_gods:.2f} years.")
    print(f"The average age of goddesses is {avg_age_goddesses:.2f} years.")
else:
    print("There is no significant age difference between gods and goddesses.")
# Out:
# Gods tend to be older than goddesses.
# The average age of gods is 9000.00 years.
# The average age of goddesses is 7700.00 years.

# %% [markdown]
# 7. Write a Python program using for loop to iterate over the "Age" column of the merged table (after merging the gods and goddesses tables) and print out the names of gods/goddesses who are older than 8000 years

# %%
df4
# Out:
#           God                   Domain         Symbol    Age   Gender
# 0        Zeus         King of the Gods    Thunderbolt  10000      God
# 1    Poseidon           God of the Sea        Trident   9000      God
# 2        Hera        Queen of the Gods        Peacock   8500      God
# 3      Athena        Goddess of Wisdom            Owl   8000      God
# 4       Hades    God of the Underworld         Helmet   9500      God
# 5   Aphrodite          Goddess of Love           Dove   7000  Goddess
# 6     Artemis      Goddess of the Hunt  Bow and Arrow   7500  Goddess
# 7     Demeter   Goddess of Agriculture          Wheat   8000  Goddess
# 8      Hestia    Goddess of the Hearth           Fire   8200  Goddess
# 9  Persephone  Queen of the Underworld    Pomegranate   7800  Goddess

# %%
# Iterate over the "Age" column of the merged table
for index, row in df4.iterrows():
    if row['Age'] > 8000:
        print(f"{row['God']} is older than 8000 years.")
# Out:
# Zeus is older than 8000 years.
# Poseidon is older than 8000 years.
# Hera is older than 8000 years.
# Hades is older than 8000 years.
# Hestia is older than 8000 years.

# %% [markdown]
# 8. Write a Python program to find the oldest god/goddess from the merged table Lafter merging the gods and goddesses tables) by iterating through the "Age" column using a while loop Print out the name of the oldest god/goddess and their age

# %%
# Initialize variables to store the oldest age and corresponding name
oldest_age = 0
oldest_name = ""

# Iterate through the "Age" column using a while loop
index = 0
while index < len(df4):
    current_age = df4.iloc[index]['Age']
    current_name = df4.iloc[index]['God']
    if current_age > oldest_age:
        oldest_age = current_age
        oldest_name = current_name
    index += 1

# Print out the name of the oldest god/goddess and their age
print(f"The oldest god/goddess is {oldest_name} with an age of {oldest_age} years.")
# Out:
# The oldest god/goddess is Zeus with an age of 10000 years.
